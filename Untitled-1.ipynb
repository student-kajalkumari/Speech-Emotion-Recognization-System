# %%
import pandas as pd 
import numpy as np 
import os 
import seaborn as sns 
import matplotlib.pyplot as plt 
import librosa 
import librosa.display 
from IPython.display import Audio 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# load the datasets

# %%
paths = [] 
labels = []
for dirname, _,filenames in os.walk(r"D:\archive\TESS Toronto emotional speech set data"):
    for filename in filenames:
        paths.append(os.path.join(dirname,filename))
        label = filename.split('_')[-1] 
        label = label.split('.')[0] 
        labels.append(label.lower())
print("Dataset is loaded ")
# Out:
# Dataset is loaded

# %%
paths[:5]
# Out:
# ['D:\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'D:\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'D:\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'D:\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'D:\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataFrame 
df = pd.DataFrame() 
df['speech']=paths 
df['label']=labels 
df.head()
# Out:
#                                               speech  label
# 0  D:\archive\TESS Toronto emotional speech set d...  angry
# 1  D:\archive\TESS Toronto emotional speech set d...  angry
# 2  D:\archive\TESS Toronto emotional speech set d...  angry
# 3  D:\archive\TESS Toronto emotional speech set d...  angry
# 4  D:\archive\TESS Toronto emotional speech set d...  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      800
# disgust    800
# fear       800
# happy      800
# neutral    800
# ps         800
# sad        800
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(df['label'])
# Out:
# <Axes: xlabel='count', ylabel='label'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
def spectrogram(data, sr, emotion):
    x=librosa.stft(data)
    xdb=librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()
    plt.show()

# %%
emotion = 'angry'
path=df['speech'][df['label']==emotion][0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'fear'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path=np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275578e+00,  1.00753632e+01, -2.03667068e+01, -6.09245014e+00,
#        -7.21228313e+00, -5.57365894e-01, -1.83255363e+00,  2.02101767e-01,
#         7.27550745e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651104e+00, -1.62115932e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722819e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996351e+00, -1.82390726e+00,
#         4.86896276e+00,  9.31392288e+00,  2.08915043e+00, -1.90649104e+00],
#       dtype=float32)

# %%
x_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
x_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600884, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550473, -0.21709493, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 5595    [-406.48053, 80.379875, 32.462395, 46.579094, ...
# 5596    [-426.90918, 102.54757, 24.800041, 43.048096, ...
# 5597    [-378.50494, 80.91062, 35.300533, 39.74792, -4...
# 5598    [-434.8618, 89.90637, 28.373262, 39.57707, -2....
# 5599    [-421.8341, 70.69788, 32.476387, 45.642555, 4....
# Name: speech, Length: 5600, dtype: object

# %%
x=[x for x in x_mfcc]
x = np.array(x)
x.shape
# Out:
# (5600, 40)

# %%
## input split 
x =np.expand_dims(x_mfcc, -1)
x.shape
# Out:
# (5600, 1)

# %% [markdown]
# from keras.utils import to_categorical
# y = to_categorical(df['label'])
# y.shape

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder()
y=enc.fit_transform(df[['label']])

# %%
y=y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %% [markdown]
# Create the LSTM MODEL

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
   LSTM(123, return_sequences=False, input_shape=(40,1)),
   Dense(64, activation='relu'),
   Dropout(0.2),
   Dense(32, activation='relu'),
   Dropout(0.2),
   Dense(7, activation='softmax')

])
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 123)               61500
#
#  dense (Dense)               (None, 64)                7936
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 71,747
# Trainable params: 71,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(type(x), x.dtype, x.shape)
print(type(y), y.dtype, y.shape)
# Out:
# <class 'numpy.ndarray'> object (5600, 1)
# <class 'numpy.ndarray'> float64 (5600, 7)

# %%
print(type(x), x.dtype)
print(type(y), y.dtype)
print(len(x), len(x[0]))   # check first element length
# Out:
# <class 'numpy.ndarray'> object
# <class 'numpy.ndarray'> float64
# 5600 1

# %%
import numpy as np
import librosa

def extract_mfcc_fixed(file_path, n_mfcc=40):
    y, sr = librosa.load(file_path, duration=3, offset=0.5)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_scaled = np.mean(mfcc.T, axis=0)   # shape: (n_mfcc,)
    return mfcc_scaled

# %%
files = df['speech'].tolist()  # assuming 'speech' column me file paths hain

x = np.array([extract_mfcc_fixed(f) for f in files])
y = np.array(y)   # agar one-hot ya numeric

# %%
##Train The model
history = model.fit(x,y, validation_split=0.2, epochs=100, batch_size=512, shuffle=True)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 6s 365ms/step - loss: 1.8351 - accuracy: 0.3092 - val_loss: 1.7732 - val_accuracy: 0.3598
# Epoch 2/100
# 9/9 [==============================] - 2s 261ms/step - loss: 1.5581 - accuracy: 0.4605 - val_loss: 1.5172 - val_accuracy: 0.4339
# Epoch 3/100
# 9/9 [==============================] - 2s 258ms/step - loss: 1.2051 - accuracy: 0.5458 - val_loss: 1.1103 - val_accuracy: 0.5312
# Epoch 4/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0
100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0359 - accuracy: 0.9906 - val_loss: 0.0188 - val_accuracy: 0.9937
# Epoch 48/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.0155 - val_accuracy: 0.9955
# Epoch 49/100
# 9/9 [==============================] - 2s 248ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0103 - val_accuracy: 0.9973
# Epoch 50/100
# 9/9 [==============================] - 2s 248ms/step - loss: 0.0240 - accuracy: 0.9933 - val_loss: 0.0212 - val_accuracy: 0.9920
# Epoch 51/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.0064 - val_accuracy: 0.9982
# Epoch 52/100
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.0049 - val_accuracy: 0.9982
# Epoch 53/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0069 - val_accuracy: 0.9973
# Epoch 54/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0119 - accuracy: 0.9971 - val_loss: 0.0069 - val_accuracy: 0.9982
# Epoch 55/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0135 - accuracy: 0.9946 - val_loss: 0.0053 - val_accuracy: 0.9973
# Epoch 56/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0042 - val_accuracy: 0.9982
# Epoch 57/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 58/100
# 9/9 [==============================] - 2s 248ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.0039 - val_accuracy: 0.9982
# Epoch 59/100
# 9/9 [==============================] - 2s 282ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.0076 - val_accuracy: 0.9964
# Epoch 60/100
# 9/9 [==============================] - 2s 279ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0038 - val_accuracy: 0.9991
# Epoch 61/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.0047 - val_accuracy: 0.9982
# Epoch 62/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.0029 - val_accuracy: 0.9991
# Epoch 63/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0074 - val_accuracy: 0.9973
# Epoch 64/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 65/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0181 - accuracy: 0.9955 - val_loss: 0.0077 - val_accuracy: 0.9964
# Epoch 66/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0362 - accuracy: 0.9902 - val_loss: 0.0054 - val_accuracy: 0.9982
# Epoch 67/100
# 9/9 [==============================] - 2s 250ms/step - loss: 0.0274 - accuracy: 0.9926 - val_loss: 0.0205 - val_accuracy: 0.9946
# Epoch 68/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.0054 - val_accuracy: 0.9982
# Epoch 69/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0051 - val_accuracy: 0.9982
# Epoch 70/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 71/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0043 - val_accuracy: 0.9982
# Epoch 72/100
# 9/9 [==============================] - 2s 250ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 73/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 74/100
# 9/9 [==============================] - 2s 273ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 75/100
# 9/9 [==============================] - 2s 249ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9991
# Epoch 76/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 77/100
# 9/9 [==============================] - 2s 247ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 78/100
# 9/9 [==============================] - 2s 248ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 0.9991
# Epoch 79/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.0037 - val_accuracy: 0.9991
# Epoch 80/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 81/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 82/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0023 - val_accuracy: 0.9991
# Epoch 83/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 84/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 85/100
# 9/9 [==============================] - 2s 250ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0022 - val_accuracy: 0.9991
# Epoch 86/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 87/100
# 9/9 [==============================] - 2s 246ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0015 - val_accuracy: 0.9991
# Epoch 88/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 89/100
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 90/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 91/100
# 9/9 [==============================] - 2s 245ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 9.7898e-04 - val_accuracy: 0.9991
# Epoch 92/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 93/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0015 - val_accuracy: 0.9991
# Epoch 94/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0021 - val_accuracy: 0.9982
# Epoch 95/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0040 - val_accuracy: 0.9982
# Epoch 96/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.0712 - accuracy: 0.9833 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 97/100
# 9/9 [==============================] - 2s 271ms/step - loss: 0.0293 - accuracy: 0.9922 - val_loss: 0.0116 - val_accuracy: 0.9955
# Epoch 98/100
# 9/9 [==============================] - 2s 250ms/step - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 99/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0125 - val_accuracy: 0.9964
# Epoch 100/100
# 9/9 [==============================] - 2s 249ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0014 - val_accuracy: 1.0000

# %% [markdown]
# ## plot the result

# %%
epochs = list(range(100))
acc  = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss  = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
